# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#               name  age  gender date_of_joining                     email  \
# 0      Jewell Long   54   Other      09/10/2005       arthur2026@duck.com
# 1     Corey Kramer   38    Male      10/14/2015  dominican2071@yandex.com
# 2  Arron Underwood   43  Female      08/12/2019          rid1894@duck.com
# 3  Garfield Levine   17   Other      01/06/2001        pants2083@live.com
# 4  Zachary Webster   66    Male      11/12/2000       few1824@example.com
#
#             occupation                  employer        city       state  \
# 0  Instrument Engineer  Emerson Electric Company   Gladstone     Wyoming
# 1          Stable Hand        Safeco Corporation      Laredo    Kentucky
# 2         Sportsperson            VF Corporation  San Angelo    Missouri
# 3        Steel Erector                  DC Shoes    Radcliff  California
# 4         Pallet Maker                    Fiserv   Manitowoc        Iowa
#
#          country  nationality                                     ipv6  \
# ...

# %%
df.columns
# Out:
# Index(['name', 'age', 'gender', 'date_of_joining', 'email', 'occupation',
#        'employer', 'city', 'state', 'country', 'nationality', 'ipv6', 'ipv4',
#        'mac_address'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1700 non-null   object
#  1   age              1700 non-null   int64
#  2   gender           1700 non-null   object
#  3   date_of_joining  1700 non-null   object
#  4   email            1700 non-null   object
#  5   occupation       1700 non-null   object
#  6   employer         1700 non-null   object
#  7   city             1700 non-null   object
#  8   state            1700 non-null   object
#  9   country          1700 non-null   object
#  10  nationality      1700 non-null   object
#  11  ipv6             1700 non-null   object
#  12  ipv4             1700 non-null   object
#  13  mac_address      1700 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 186.1+ KB

# %%
df.loc[df['name'] == 'Lewis Castillo']
# Out:
#                 name  age  gender date_of_joining                email  \
# 755   Lewis Castillo   29  Female      08/07/2000    grad2007@duck.com
# 1380  Lewis Castillo   46   Other      11/02/2017  resume1907@duck.com
#
#            occupation                  employer    city      state  \
# 755   Marquee Erector  Platinum Interior Design  Moraga  Wisconsin
# 1380          Auditor                 Cole Haan  Howard    Montana
#
#             country nationality                                     ipv6  \
# 755   United States   Jordanian  b293:8f6b:9b2e:acdf:2fe7:411e:42fa:f652
# 1380  United States     Russian  6103:e72b:1164:8fb0:3055:c0d2:d119:1c1c
#
#                 ipv4        mac_address
# 755   204.53.249.181  00:16:3e:29:c5:02
# 1380  230.10.250.192  00:16:3e:4a:fe:62

# %%
df = df.drop(1380)

# %%
df[['email_id','email_provider']] = df['email'].str.split("@",1,expand=True)

# %%
df = df.drop('email_id',axis=1)
df = df.drop('email',axis=1)

# %%
df.nunique()
# Out:
# name               1699
# age                  51
# gender                3
# date_of_joining    1547
# occupation          880
# employer            884
# city               1091
# state                50
# country               1
# nationality          50
# ipv6               1699
# ipv4               1699
# mac_address        1699
# email_provider        9
# dtype: int64

# %%
df.head()
# Out:
#               name  age  gender date_of_joining           occupation  \
# 0      Jewell Long   54   Other      09/10/2005  Instrument Engineer
# 1     Corey Kramer   38    Male      10/14/2015          Stable Hand
# 2  Arron Underwood   43  Female      08/12/2019         Sportsperson
# 3  Garfield Levine   17   Other      01/06/2001        Steel Erector
# 4  Zachary Webster   66    Male      11/12/2000         Pallet Maker
#
#                    employer        city       state        country  \
# 0  Emerson Electric Company   Gladstone     Wyoming  United States
# 1        Safeco Corporation      Laredo    Kentucky  United States
# 2            VF Corporation  San Angelo    Missouri  United States
# 3                  DC Shoes    Radcliff  California  United States
# 4                    Fiserv   Manitowoc        Iowa  United States
#
#    nationality                                     ipv6             ipv4  \
# ...

# %%
df.to_excel("powerbi.xlsx",index=False)

# %%
cityDf = df.groupby("city")['name'].agg(["count"]).sort_values(by='count',ascending=False)
